# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
import re
t = {}
lasts = -1
with open('result_sizes') as f:
    for l in f:
        m = re.search('size: (\d+)', l)
        if m != None:
            lasts = int(m.group(1))
        m = re.search('(\d+) ns/op', l)
        if m != None:
            t[lasts] = int(m.group(1))
            
t2 = {}
lasts = -1
with open('result_sizes2') as f:
    for l in f:
        m = re.search('size: (\d+)', l)
        if m != None:
            lasts = int(m.group(1))
        m = re.search('(\d+) ns/op', l)
        if m != None:
            t2[lasts] = int(m.group(1))

# %%
df = pd.DataFrame(t, index=[0]).T
df2 = pd.DataFrame(t2, index=[0]).T

# %%
df
# Out:
#                0
# 0     1065223767
# 5      164128120
# 13     158644271
# 21     163156071
# 29     159395421
# 37     162872326
# 45     165355215
# 53     158391930
# 61     160830178
# 69     163407620
# 77     169079376
# 85     166987465
# 93     169483293
# 101    160622454
# 109    164904172
# 117    162000372
# 125    163095031
# 133    162799388
# 141    163175452
# 149    160841334
# 157    163710470
# 165    156820773
# 173    164467078
# 181    160415584
# 189    161624563
# 197    160932986
# 205    166005947
# 213    169590898
# 221    161336498
# 229    168299152
# ...          ...
# 3861   164858093
# 3869   172051667
# 3877   173949310
# 3885   165764537
# 3893   166612305
# 3901   163608297
# 3909   165617958
# 3917   170892255
# 3925   163838627
# 3933   165318476
# 3941   166444401
# 3949   182220910
# 3957   170676376
# 3965   181988242
# 3973   161629609
# 3981   170291166
# 3989   166205861
# 3997   163807304
# 4005   166717437
# 4013   175481091
# ...

# %%
df2
# Out:
#               0
# 0     942683201
# 5     168412386
# 13    158768801
# 21    164325940
# 29    176047246
# 37    165349959
# 45    164230712
# 53    166331238
# 61    167314988
# 69    165310375
# 77    161858745
# 85    162933561
# 93    168760726
# 101   169872054
# 109   167211013
# 117   160172076
# 125   159593829
# 133   161771081
# 141   160577422
# 149   166105726
# 157   164685651
# 165   165120924
# 173   181652130
# 181   166487256
# 189   175961477
# 197   175317493
# 205   163458526
# 213   169648565
# 221   177195211
# 229   168635145
# ...         ...
# 3861  165878631
# 3869  170060566
# 3877  170040198
# 3885  165638309
# 3893  163877254
# 3901  158552335
# 3909  162989405
# 3917  159914451
# 3925  160374447
# 3933  160137645
# 3941  162232939
# 3949  167635508
# 3957  158084760
# 3965  162759615
# 3973  154761165
# 3981  158609653
# 3989  162952583
# 3997  164152700
# 4005  162875446
# 4013  161697448
# 4021  160182334
# 4029  164922455
# 4037  162534278
# ...

# %%
df.plot()

# %%
df[1:].plot()

# %%
df2.plot()

# %%
df2[1:].plot()
