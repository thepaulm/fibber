# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
with open('linux_results_0') as f:
    d0 = [l.split('\t')[2].split()[0] for l in f]

# %%
with open('linux_results_5') as f:
    d5 = [l.split('\t')[2].split()[0] for l in f]

# %%
df0 = pd.DataFrame(d0)

# %%
df5 = pd.DataFrame(d5)

# %%
df0[0] = pd.to_numeric(df0[0])
df5[0] = pd.to_numeric(df5[0])

# %%
df0 = df0.apply(lambda x: x / (1000 * 1000))
df5 = df5.apply(lambda x: x / (1000 * 1000))

# %%
plt.style.use('ggplot')

# %%
data0 = pd.DataFrame({"pad0 infinite": df0[0:6][0].values, "pad0 2": df0[6:12][0].values, "pad0 4": df0[12:18][0].values}, index=[1, 2, 4, 8, 24, 32])
data5 = pd.DataFrame({"pad5 infinite": df5[0:6][0].values, "pad5 2": df5[6:12][0].values, "pad5 4": df5[12:18][0].values}, index=[1, 2, 4, 8, 24, 32])

# %%
data0.plot(subplots=True)
data5.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x116e297f0>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x116ec0780>], dtype=object)

# %%
f, (ax1, ax2) = plt.pyplot.subplots(1, 2, sharey=True, figsize=(12,4))
data0.plot(ax=ax1, title="0 fill")
data5.plot(ax=ax2, title="5 fill")

# %%
data0.plot()

# %%
data5.plot()

# %%
pd.concat([pd.DataFrame(data5['pad5 2']), pd.DataFrame(data0['pad0 2'])]).plot()

# %%
pd.concat([pd.DataFrame(data5['pad5 4']), pd.DataFrame(data0['pad0 4'])]).plot()

# %%
pd.concat([pd.DataFrame(data5['pad5 infinite']), pd.DataFrame(data0['pad0 infinite'])]).plot()
