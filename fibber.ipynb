# %%
with open('results_0') as f:
    d0 = [l.split('\t')[2].split()[0] for l in f]

# %%
with open('results_5') as f:
    d5 = [l.split('\t')[2].split()[0] for l in f]

# %%
d0, d5
# Out:
# (['1088632229',
#   '1542166174',
#   '609168793',
#   '518119435',
#   '458651309',
#   '529896912',
#   '1102473079',
#   '1257765196',
#   '1996834105',
#   '1848116555',
#   '2040387717',
#   '2011531209',
#   '1458512821',
#   '1336123788',
#   '748880938',
#   '812670463',
#   '809775753',
#   '805183412'],
#  ['1055397185',
#   '549028853',
#   '460269357',
#   '515042951',
#   '444739635',
#   '464671345',
#   '1151835985',
#   '543520258',
#   '788996382',
#   '1292329663',
#   '1383424664',
#   '1299055500',
#   '1220359588',
#   '555053726',
#   '510659598',
#   '548605056',
#   '674599195',
#   '826141188'])

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
df0 = pd.DataFrame(d0)

# %%
df5 = pd.DataFrame(d5)

# %%
df0[0] = pd.to_numeric(df0[0])
df5[0] = pd.to_numeric(df5[0])

# %%
plt.style.use('ggplot')

# %%
o0 = df[0:6]

# %%
o2 = df[6:12]

# %%
o4 = df[12:18]

# %%
data0 = pd.DataFrame({"pad0 0": df0[0:6][0].values, "pad0 2": df0[6:12][0].values, "pad0 4": df0[12:18][0].values}, index=[1, 2, 4, 8, 24, 32])
data5 = pd.DataFrame({"pad5 0": df5[0:6][0].values, "pad5 2": df5[6:12][0].values, "pad5 4": df5[12:18][0].values}, index=[1, 2, 4, 8, 24, 32])

# %%
data0.plot()

# %%
data5.plot()

# %%
pd.concat([data0, data5]).plot()

# %%
pd.concat([pd.DataFrame(data5['pad5 0']), pd.DataFrame(data0['pad0 0'])]).plot()

# %%
pd.concat([pd.DataFrame(data5['pad5 2']), pd.DataFrame(data0['pad0 2'])]).plot()

# %%
pd.concat([pd.DataFrame(data5['pad5 4']), pd.DataFrame(data0['pad0 4'])]).plot()
